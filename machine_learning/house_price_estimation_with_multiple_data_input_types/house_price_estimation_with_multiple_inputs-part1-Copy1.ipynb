# %% [markdown]
# <div class="alert" style="background-color:#fff; color:white; padding:0px 10px; border-radius:5px;"><h1 style='margin:15px 15px; color:#006a79; font-size:40px'>House price estimation with multiple input</h1>
# </div>
#
# In this notebook, you will see how to use the functional Keras API to implement a regressor with neural networks wich receive as input differents data types. This is a continuation of the previous notebook where only numerical data type was used. In this new one I will use both house image data and numerical data to house price estimation.
#
# ## Content
#
# 1. Load the Data
#     - Import libraries.
#     - Load the datasets.
#
# 2. Overview of the Data.
#     - Descriptive Statistics.
#     - Missing Values.
#
# 3. Exploratory Data Analysis.
#     - Create a list of columns by data type.
#     - Check the distribution of target class
#     - Check the distribution of every feature.
#
# 4. Data Preparation.
#     - Data Cleaning.
#     - Feature encoding.
#     - Split X & Y
#     - Feature Scaling.
#
# 5. Model Building.
#     - Defining the model.
#     - Train model.
#     - Model prediction.
#     - Model evaluation.
#
# 6. Improve the model.
#     - Handle the outlier values.
#     - Scaling the data.
#     - Building the new model.
#     - Training the new model.
#     - Model prediction.
#     - Model evaluation.
#     - Saving the model.
#
# 7. Conclusions.

# %% [markdown]
# <div class="alert alert-info" style="background-color:#006a79; color:white; padding:0px 10px; border-radius:5px;"><h2 style='margin:10px 5px'>1. Load the Data</h2>
# </div>
#
# In this section you will:
#
# - Import the libraries.
# - Load the dataset.
#
# ### 1.1 Import Libraries

# %%
#Import libraries

import os

# Machine Learning
import tensorflow as tf
from tensorflow.keras.layers import Dense, Input, Conv2D, MaxPool2D, Flatten, Concatenate
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

#Data visualization
import seaborn as sn
import matplotlib.pyplot as plt

#Image Manipulation 
import cv2

#Data Manipulation
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1.2 Load the datasets
#
# In the previous notebook a processed dataset was generated, I am going to use that dataset to feed the model and to get the images

# %%
#dataset path
#change this path for you data path
num_data_path = "output/final_house_price_prediction.csv"
image_data_path = "../../../Houses-dataset/Houses-Dataset/"

#read the data
df = pd.read_csv(num_data_path)
df.head()
# Out:
#    Unnamed: 0  z_91901  z_92276  z_92677  z_92880  z_93446  z_93510  z_94501  \
# 0          32        0        0        0        0        1        0        0
# 1          39        0        0        0        0        1        0        0
# 2          80        1        0        0        0        0        0        0
# 3          81        1        0        0        0        0        0        0
# 4          82        1        0        0        0        0        0        0
#
#    z_94531  bedrooms  bathrooms  area   price
# 0        0         3        2.0  1802  365000
# 1        0         3        3.0  2146  455000
# 2        0         4        2.5  2464  599000
# 3        0         2        2.0  1845  529800
# 4        0         2        1.0  1184  397500

# %%
#change the column called "unnamed" which represents the house number
df.rename(columns={'Unnamed: 0':"idx"}, inplace= True)
df.head()
# Out:
#    idx  z_91901  z_92276  z_92677  z_92880  z_93446  z_93510  z_94501  \
# 0   32        0        0        0        0        1        0        0
# 1   39        0        0        0        0        1        0        0
# 2   80        1        0        0        0        0        0        0
# 3   81        1        0        0        0        0        0        0
# 4   82        1        0        0        0        0        0        0
#
#    z_94531  bedrooms  bathrooms  area   price
# 0        0         3        2.0  1802  365000
# 1        0         3        3.0  2146  455000
# 2        0         4        2.5  2464  599000
# 3        0         2        2.0  1845  529800
# 4        0         2        1.0  1184  397500

# %%
#lets to create an array to content the image data

def stack_images(ims):
    
    ims = [cv2.resize(im,(120,120)) for im in ims]
    im1 = np.hstack((ims[0],ims[1]))
    im2 = np.hstack((ims[2],ims[3]))
    im = np.vstack((im1,im2))
    return im
    
    

def load_images(image_path, idx_list):
    
    images = os.listdir(image_path)
    images = [im for im in images if im.split(".")[-1] =="jpg" and int(im.split("_")[0]) in idx_list]
    images.sort()
    
    ims = []
    image_dataset = []
    for n in range(len(images)):
        ims.append(cv2.imread(os.path.join(image_path,images[n])))
        if len(ims)==4:
            idx = images[n].split("_")[0]
            image_dataset.append([idx,stack_images(ims)])
            ims = []
    
    return image_dataset

# %%
image_dataset = load_images(image_data_path, df.idx.values)

# %% [markdown]
# <div class="alert alert-info" style="background-color:#006a79; color:white; padding:0px 10px; border-radius:5px;"><h2 style='margin:10px 5px'>2. Overview of the Data.</h2>
# </div>
#
# The dataset I'll use for this project can be found in the next [link](https://github.com/emanhamed/Houses-dataset), this dataset contains both visual and textual information for house prices estimation. Each house in the dataset is represented by four images for bedroom, bathroom, kitchen and frontal image of the house.
#
# The dataset also contains a text file with textual metadata, each row represents the number of houses in order. The numbers represent the number of bedrooms, number of bathrooms, area of the house, zip code and the price.
#
# This dataset was processed in the previous notebook, in this one I am going to focus more in the image dataset
#
# ### 2.1 Image dataset
#
# Let's see how our image dataset looks

# %%
fig, axs = plt.subplots(2,2,figsize = (12,12))
for axi in axs:
    for ax in axi:
        idx = np.random.randint(len(image_dataset))
        ax.imshow(cv2.cvtColor(image_dataset[idx][1], cv2.COLOR_BGR2RGB))
        ax.set_title(image_dataset[idx][0])
        ax.axis("off")

# %% [markdown]
# In the figure above we can see how the images represent four different houses. We can see the index in the house as well, I will use it to link with the respective rows in the dataframe.

# %% [markdown]
# <div class="alert alert-info" style="background-color:#006a79; color:white; padding:0px 10px; border-radius:5px;"><h2 style='margin:10px 5px'>3.Create the dataset.</h2>
# </div>
#
# In this scenario we have a dataset formed by two kind of data, I am going to create an array to link this types of data.

# %%
def create_dataset(image_dataset, num_dataset=None):
    
    X_num = []
    X_im = []
    Y = []
    for idx, im in image_dataset:
        X_num += [num_dataset[num_dataset["idx"] == int(idx)].values.flatten()[0:-1]]
        X_im += [im/255.]
        Y.append(num_dataset[num_dataset["idx"] == int(idx)].values.flatten()[-1])
    
    return X_num,X_im, Y

# %%
df = df.sample(frac = 1).reset_index(drop = False)
X_num, X_im, Y = create_dataset(image_dataset, df)

X_num = np.array(X_num)
X_im = np.array(X_im)
Y = np.array(Y)

# %% [markdown]
# <div class="alert alert-info" style="background-color:#006a79; color:white; padding:0px 10px; border-radius:5px;"><h2 style='margin:10px 5px'>4. Train test split</h2>
# </div>
#
#
#
# I will split the data into training and testing data sets, also I am going to scale the numerical data.

# %%
train_size = int(0.8 * len(X_num))

X_num_train = X_num[0:train_size]
X_im_train = X_im[0:train_size]
Y_train = Y[0:train_size]

X_num_test = X_num[train_size:]
X_im_test = X_im[train_size:]
Y_test = Y[train_size:]

#scaling the data
scaler = MinMaxScaler()

X_num_train_scaled = scaler.fit_transform(X_num_train)
Y_train_scaled = Y_train/max(Y_train)

X_num_test_scaled = scaler.transform(X_num_test)
Y_test_scaled = Y_test/max(Y_train)

# %% [markdown]
# <div class="alert alert-info" style="background-color:#006a79; color:white; padding:0px 10px; border-radius:5px;"><h2 style='margin:10px 5px'>5. Model building</h2>
# </div>
#
# ### 5.1 Defining the model.
#
# In this scenario I will need to create a special neural network architecture so I will be able to feed it using both types of data that we have

# %%
def create_model(input_num_shape, input_image_shape):

    #Numerical input layer
    input_num_layer = Input(shape = input_num_shape, name ="numerical_input")
    #first_dense_num = Dense(16, activation = "relu")(input_num_layer)
    #second_dense_num = Dense(8, activation = "relu")(first_dense_num)
    
    # Image input layer 
    input_image_layer = Input(shape= input_image_shape, name ="image_input")
    
    #Convolutional layers -> image
    conv_1 = Conv2D(32,3,activation = "relu")(input_image_layer)
    max_pooling_1 = MaxPool2D((2,2))(conv_1)
    conv_2 = Conv2D(32,3, activation = "relu")(max_pooling_1)
    max_pooling_2 = MaxPool2D((2,2))(conv_2)
    conv_3 = Conv2D(16,3, activation = "relu")(max_pooling_2)
    flatten = Flatten()(conv_2)
    
    #combining the two ways
    mix_layer = Concatenate()([flatten, input_num_layer])
    
    #dense layers
    first_dense = Dense(16, activation = "relu")(mix_layer)
    second_dense = Dense(8, activation = "relu")(first_dense)
    
    #last layer (regression output)
    last_layer = Dense(1, activation ="linear")(mix_layer)

    #creating the model
    model = Model(inputs = [input_num_layer, input_image_layer], outputs = last_layer)
    
    return model

model = create_model(input_num_shape=X_num_train.shape[1], input_image_shape = X_im_train.shape[1:])

#plot model
plot_model(model, show_shapes=True)

# %% [markdown]
# ### 5.2 Train the model.
#
# To train the model I need to use the compile method to define the loss function and the metric to be used.

# %%
#use adam optimizer
optimizer = tf.keras.optimizers.Adam(lr=0.001)

#use mean absolute error as loss function
model.compile(optimizer= optimizer, loss="mae")

#train the model
history = model.fit(
    x = (X_num_train_scaled,X_im_train),
    y = Y_train_scaled,
    epochs = 200,
    validation_data = ((X_num_test_scaled,X_im_test),Y_test_scaled),
    batch_size = 16,
    verbose = 1
)
# Out:
# Epoch 1/200
# 16/16 [==============================] - 14s 852ms/step - loss: 2.5454 - val_loss: 0.3086
# Epoch 2/200
# 16/16 [==============================] - 9s 591ms/step - loss: 0.4048 - val_loss: 0.3639
# Epoch 3/200
# 16/16 [==============================] - 9s 564ms/step - loss: 0.2858 - val_loss: 0.2852
# Epoch 4/200
# 16/16 [==============================] - 9s 565ms/step - loss: 0.2348 - val_loss: 0.2061
# Epoch 5/200
# 16/16 [==============================] - 9s 570ms/step - loss: 0.1671 - val_loss: 0.1816
# Epoch 6/200
# 16/16 [==============================] - 9s 562ms/step - loss: 0.1190 - val_loss: 0.2047
# Epoch 7/200
# 16/16 [==============================] - 9s 565ms/step - loss: 0.0961 - val_loss: 0.2082
# Epoch 8/200
# 16/16 [==============================] - 9s 571ms/step - loss: 0.0873 - val_loss: 0.1906
# Epoch 9/200
# 16/16 [==============================] - 9s 562ms/step - loss: 0.0883 - val_loss: 0.1933
# Epoch 10/200
# 16/16 [==============================] - 9s 565ms/step - loss: 0.0704 - val_loss: 0.2047
# Epoch 11/200
# 16/16 [==============================] - 9s 567ms/step - loss: 0.0737 - val_loss: 0.2107
# Epoch 12/200
# 16/16 [==============================] - 9s 566ms/step - loss: 0.0723 - val_loss: 0.2193
# Epoch 13/200
# 16/16 [==============================] - 9s 561ms/step - loss: 0.0882 - val_loss: 0.2406
# Epoch 14/200
# 16/16 [==============================] - 9s 565ms/step - loss: 0.1009 - val_loss: 0.2291
# Epoch 15/200
# 16/16 [==============================] - 9s 568ms/step - loss: 0.0957 - val_loss: 0.1975
# Epoch 16/200
# 16/16 [==============================] - 9s 568ms/step - loss: 0.0771 - val_loss: 0.2111
# Epoch 17/200
# 16/16 [==============================] - 9s 563ms/step - loss: 0.0809 - val_loss: 0.2049
# Epoch 18/200
# 16/16 [==============================] - 10s 600ms/step - loss: 0.0555 - val_loss: 0.1813
# Epoch 19/200
# 16/16 [==============================] - 9s 563ms/step - loss: 0.0665 - val_loss: 0.1867
# Epoch 20/200
# 16/16 [==============================] - 10s 595ms/step - loss: 0.0634 - val_loss: 0.1892
# Epoch 21/200
# 16/16 [==============================] - 9s 566ms/step - loss: 0.0634 - val_loss: 0.2012
# Epoch 22/200
# 16/16 [==============================] - 9s 569ms/step - loss: 0.0492 - val_loss: 0.1826
# Epoch 23/200
# 16/16 [==============================] - 9s 563ms/step - loss: 0.0657 - val_loss: 0.2034
# Epoch 24/200
# 16/16 [==============================] - 9s 565ms/step - loss: 0.0417 - val_loss: 0.1749
# Epoch 25/200
# 16/16 [==============================] - 9s 567ms/step - loss: 0.0599 - val_loss: 0.1940
# Epoch 26/200
# 16/16 [==============================] - 9s 565ms/step - loss: 0.0400 - val_loss: 0.1954
# Epoch 27/200
# 16/16 [==============================] - 9s 563ms/step - loss: 0.0532 - val_loss: 0.2208
# Epoch 28/200
# 16/16 [==============================] - 9s 566ms/step - loss: 0.0547 - val_loss: 0.2031
# Epoch 29/200
# 16/16 [==============================] - 9s 573ms/step - loss: 0.0487 - val_loss: 0.1831
# Epoch 30/200
# 16/16 [==============================] - 9s 579ms/step - loss: 0.0599 - val_loss: 0.2177
# Epoch 31/200
# 16/16 [==============================] - 9s 570ms/step - loss: 0.0500 - val_loss: 0.1903
# Epoch 32/200
# 16/16 [==============================] - 9s 567ms/step - loss: 0.0408 - val_loss: 0.1862
# Epoch 33/200
# 16/16 [==============================] - 9s 571ms/step - loss: 0.0383 - val_loss: 0.1713
# Epoch 34/200
# 16/16 [==============================] - 9s 571ms/step - loss: 0.0395 - val_loss: 0.1712
# Epoch 35/200
# 16/16 [==============================] - 9s 569ms/step - loss: 0.0399 - val_loss: 0.1971
# Epoch 36/200
# 16/16 [==============================] - 9s 576ms/step - loss: 0.0359 - val_loss: 0.1784
# Epoch 37/200
# 16/16 [==============================] - 9s 567ms/step - loss: 0.0531 - val_loss: 0.1859
# Epoch 38/200
# 16/16 [==============================] - 9s 565ms/step - loss: 0.0492 - val_loss: 0.1774
# Epoch 39/200
# 16/16 [==============================] - 9s 565ms/step - loss: 0.0521 - val_loss: 0.2050
# Epoch 40/200
# 16/16 [==============================] - 9s 568ms/step - loss: 0.0600 - val_loss: 0.1809
# Epoch 41/200
# 16/16 [==============================] - 9s 565ms/step - loss: 0.0654 - val_loss: 0.2156
# Epoch 42/200
# 16/16 [==============================] - 9s 571ms/step - loss: 0.0569 - val_loss: 0.1777
# Epoch 43/200
# 16/16 [==============================] - 9s 574ms/step - loss: 0.0395 - val_loss: 0.1975
# Epoch 44/200
# 16/16 [==============================] - 9s 571ms/step - loss: 0.0331 - val_loss: 0.1889
# Epoch 45/200
# 16/16 [==============================] - 9s 569ms/step - loss: 0.0305 - val_loss: 0.1997
# Epoch 46/200
# 16/16 [==============================] - 9s 568ms/step - loss: 0.0313 - val_loss: 0.2045
# Epoch 47/200
# 16/16 [==============================] - 9s 572ms/step - loss: 0.0413 - val_loss: 0.1900
# Epoch 48/200
# 16/16 [==============================] - 9s 563ms/step - loss: 0.0284 - val_loss: 0.1921
# Epoch 49/200
# 16/16 [==============================] - 9s 572ms/step - loss: 0.0233 - val_loss: 0.1827
# Epoch 50/200
# 16/16 [==============================] - 9s 574ms/step - loss: 0.0323 - val_loss: 0.1937
# Epoch 51/200
# 16/16 [==============================] - 9s 573ms/step - loss: 0.0281 - val_loss: 0.1945
# Epoch 52/200
# 16/16 [==============================] - 9s 572ms/step - loss: 0.0313 - val_loss: 0.1854
# Epoch 53/200
# 16/16 [==============================] - 9s 564ms/step - loss: 0.0277 - val_loss: 0.1841
# Epoch 54/200
# 16/16 [==============================] - 9s 572ms/step - loss: 0.0234 - val_loss: 0.1949
# Epoch 55/200
# 16/16 [==============================] - 9s 574ms/step - loss: 0.0266 - val_loss: 0.1931
# Epoch 56/200
# 16/16 [==============================] - 9s 563ms/step - loss: 0.0247 - val_loss: 0.1889
# Epoch 57/200
# 16/16 [==============================] - 9s 562ms/step - loss: 0.0209 - val_loss: 0.1865
# Epoch 58/200
# 16/16 [==============================] - 9s 567ms/step - loss: 0.0225 - val_loss: 0.1842
# Epoch 59/200
# 16/16 [==============================] - 9s 558ms/step - loss: 0.0215 - val_loss: 0.1880
# Epoch 60/200
# 16/16 [==============================] - 9s 563ms/step - loss: 0.0256 - val_loss: 0.1814
# Epoch 61/200
# 16/16 [==============================] - 9s 564ms/step - loss: 0.0265 - val_loss: 0.1807
# Epoch 62/200
# 16/16 [==============================] - 9s 564ms/step - loss: 0.0282 - val_loss: 0.1896
# Epoch 63/200
# 16/16 [==============================] - 9s 563ms/step - loss: 0.0253 - val_loss: 0.1873
# Epoch 64/200
# 16/16 [==============================] - 9s 564ms/step - loss: 0.0197 - val_loss: 0.1870
# Epoch 65/200
# 16/16 [==============================] - 9s 569ms/step - loss: 0.0192 - val_loss: 0.1908
# Epoch 66/200
# 16/16 [==============================] - 9s 570ms/step - loss: 0.0255 - val_loss: 0.1752
# Epoch 67/200
# 16/16 [==============================] - 9s 570ms/step - loss: 0.0264 - val_loss: 0.1913
# Epoch 68/200
# 16/16 [==============================] - 9s 564ms/step - loss: 0.0299 - val_loss: 0.1820
# Epoch 69/200
# 16/16 [==============================] - 9s 567ms/step - loss: 0.0229 - val_loss: 0.1810
# Epoch 70/200
# 16/16 [==============================] - 9s 566ms/step - loss: 0.0192 - val_loss: 0.1879
# Epoch 71/200
# 16/16 [==============================] - 9s 569ms/step - loss: 0.0203 - val_loss: 0.1814
# Epoch 72/200
# 16/16 [==============================] - 9s 570ms/step - loss: 0.0218 - val_loss: 0.1877
# Epoch 73/200
# 16/16 [==============================] - 9s 567ms/step - loss: 0.0241 - val_loss: 0.1792
# Epoch 74/200
# 16/16 [==============================] - 9s 577ms/step - loss: 0.0252 - val_loss: 0.1880
# Epoch 75/200
# 16/16 [==============================] - 9s 565ms/step - loss: 0.0204 - val_loss: 0.1828
# Epoch 76/200
# 16/16 [==============================] - 9s 568ms/step - loss: 0.0169 - val_loss: 0.1804
# Epoch 77/200
# 16/16 [==============================] - 9s 564ms/step - loss: 0.0191 - val_loss: 0.1849
# Epoch 78/200
# 16/16 [==============================] - 9s 567ms/step - loss: 0.0178 - val_loss: 0.1769
# Epoch 79/200
# 16/16 [==============================] - 9s 568ms/step - loss: 0.0164 - val_loss: 0.1789
# Epoch 80/200
# 16/16 [==============================] - 9s 577ms/step - loss: 0.0185 - val_loss: 0.1798
# Epoch 81/200
# 16/16 [==============================] - 9s 564ms/step - loss: 0.0225 - val_loss: 0.1827
# Epoch 82/200
# 16/16 [==============================] - 9s 559ms/step - loss: 0.0196 - val_loss: 0.1845
# Epoch 83/200
# 16/16 [==============================] - 9s 567ms/step - loss: 0.0203 - val_loss: 0.1769
# Epoch 84/200
# 16/16 [==============================] - 9s 564ms/step - loss: 0.0205 - val_loss: 0.1799
# Epoch 85/200
# 16/16 [==============================] - 9s 563ms/step - loss: 0.0167 - val_loss: 0.1802
# Epoch 86/200
# 16/16 [==============================] - 9s 564ms/step - loss: 0.0163 - val_loss: 0.1791
# Epoch 87/200
# 16/16 [==============================] - 9s 572ms/step - loss: 0.0181 - val_loss: 0.1758
# Epoch 88/200
# 16/16 [==============================] - 9s 566ms/step - loss: 0.0200 - val_loss: 0.1786
# Epoch 89/200
# 16/16 [==============================] - 9s 564ms/step - loss: 0.0181 - val_loss: 0.1748
# Epoch 90/200
# 16/16 [==============================] - 9s 562ms/step - loss: 0.0188 - val_loss: 0.1765
# Epoch 91/200
# 16/16 [==============================] - 9s 564ms/step - loss: 0.0153 - val_loss: 0.1786
# Epoch 92/200
# 16/16 [==============================] - 9s 572ms/step - loss: 0.0184 - val_loss: 0.1737
# Epoch 93/200
# 16/16 [==============================] - 9s 564ms/step - loss: 0.0198 - val_loss: 0.1781
# Epoch 94/200
# 16/16 [==============================] - 9s 566ms/step - loss: 0.0176 - val_loss: 0.1769
# Epoch 95/200
# 16/16 [==============================] - 9s 571ms/step - loss: 0.0150 - val_loss: 0.1755
# Epoch 96/200
# 16/16 [==============================] - 9s 564ms/step - loss: 0.0153 - val_loss: 0.1753
# Epoch 97/200
# 16/16 [==============================] - 9s 566ms/step - loss: 0.0153 - val_loss: 0.1764
# Epoch 98/200
# 16/16 [==============================] - 9s 567ms/step - loss: 0.0171 - val_loss: 0.1764
# Epoch 99/200
# 16/16 [==============================] - 9s 562ms/step - loss: 0.0153 - val_loss: 0.1747
# Epoch 100/200
# 16/16 [==============================] - 9s 557ms/step - loss: 0.0205 - val_loss: 0.1712
# Epoch 101/200
# 16/16 [==============================] - 9s 566ms/step - loss: 0.0188 - val_loss: 0.1710
# Epoch 102/200
# 16/16 [==============================] - 9s 560ms/step - loss: 0.0158 - val_loss: 0.1750
# Epoch 103/200
# 16/16 [==============================] - 9s 565ms/step - loss: 0.0137 - val_loss: 0.1724
# Epoch 104/200
# 16/16 [==============================] - 9s 566ms/step - loss: 0.0136 - val_loss: 0.1720
# Epoch 105/200
# 16/16 [==============================] - 9s 569ms/step - loss: 0.0130 - val_loss: 0.1719
# Epoch 106/200
# 16/16 [==============================] - 9s 561ms/step - loss: 0.0177 - val_loss: 0.1733
# Epoch 107/200
# 16/16 [==============================] - 9s 562ms/step - loss: 0.0161 - val_loss: 0.1694
# Epoch 108/200
# 16/16 [==============================] - 9s 564ms/step - loss: 0.0159 - val_loss: 0.1727
# Epoch 109/200
# 16/16 [==============================] - 9s 569ms/step - loss: 0.0159 - val_loss: 0.1720
# Epoch 110/200
# 16/16 [==============================] - 9s 560ms/step - loss: 0.0130 - val_loss: 0.1697
# Epoch 111/200
# 16/16 [==============================] - 9s 570ms/step - loss: 0.0142 - val_loss: 0.1697
# Epoch 112/200
# 16/16 [==============================] - 9s 567ms/step - loss: 0.0143 - val_loss: 0.1675
# Epoch 113/200
# 16/16 [==============================] - 9s 559ms/step - loss: 0.0143 - val_loss: 0.1679
# Epoch 114/200
# 16/16 [==============================] - 9s 568ms/step - loss: 0.0158 - val_loss: 0.1696
# Epoch 115/200
# 16/16 [==============================] - 9s 564ms/step - loss: 0.0163 - val_loss: 0.1707
# Epoch 116/200
# 16/16 [==============================] - 9s 568ms/step - loss: 0.0130 - val_loss: 0.1705
# Epoch 117/200
# 16/16 [==============================] - 9s 566ms/step - loss: 0.0162 - val_loss: 0.1685
# Epoch 118/200
# 16/16 [==============================] - 9s 562ms/step - loss: 0.0119 - val_loss: 0.1684
# Epoch 119/200
# 16/16 [==============================] - 9s 564ms/step - loss: 0.0126 - val_loss: 0.1698
# Epoch 120/200
# 16/16 [==============================] - 9s 567ms/step - loss: 0.0121 - val_loss: 0.1671
# Epoch 121/200
# 16/16 [==============================] - 9s 563ms/step - loss: 0.0145 - val_loss: 0.1664
# Epoch 122/200
# 16/16 [==============================] - 9s 565ms/step - loss: 0.0136 - val_loss: 0.1709
# Epoch 123/200
# 16/16 [==============================] - 9s 564ms/step - loss: 0.0162 - val_loss: 0.1700
# Epoch 124/200
# 16/16 [==============================] - 9s 569ms/step - loss: 0.0156 - val_loss: 0.1681
# Epoch 125/200
# 16/16 [==============================] - 9s 563ms/step - loss: 0.0184 - val_loss: 0.1660
# Epoch 126/200
# 16/16 [==============================] - 9s 558ms/step - loss: 0.0143 - val_loss: 0.1689
# Epoch 127/200
# 16/16 [==============================] - 9s 567ms/step - loss: 0.0125 - val_loss: 0.1674
# Epoch 128/200
# 16/16 [==============================] - 9s 562ms/step - loss: 0.0112 - val_loss: 0.1638
# Epoch 129/200
# 16/16 [==============================] - 9s 570ms/step - loss: 0.0109 - val_loss: 0.1661
# Epoch 130/200
# 16/16 [==============================] - 9s 566ms/step - loss: 0.0135 - val_loss: 0.1657
# Epoch 131/200
# 16/16 [==============================] - 10s 615ms/step - loss: 0.0141 - val_loss: 0.1660
# Epoch 132/200
# 16/16 [==============================] - 9s 558ms/step - loss: 0.0121 - val_loss: 0.1644
# Epoch 133/200
# 16/16 [==============================] - 9s 563ms/step - loss: 0.0118 - val_loss: 0.1654
# Epoch 134/200
# 16/16 [==============================] - 9s 567ms/step - loss: 0.0130 - val_loss: 0.1650
# Epoch 135/200
# 16/16 [==============================] - 9s 562ms/step - loss: 0.0139 - val_loss: 0.1677
# Epoch 136/200
# 16/16 [==============================] - 9s 567ms/step - loss: 0.0148 - val_loss: 0.1653
# Epoch 137/200
# 16/16 [==============================] - 9s 562ms/step - loss: 0.0146 - val_loss: 0.1620
# Epoch 138/200
# 16/16 [==============================] - 9s 568ms/step - loss: 0.0133 - val_loss: 0.1651
# Epoch 139/200
# 16/16 [==============================] - 9s 559ms/step - loss: 0.0143 - val_loss: 0.1666
# Epoch 140/200
# 16/16 [==============================] - 9s 560ms/step - loss: 0.0147 - val_loss: 0.1642
# Epoch 141/200
# 16/16 [==============================] - 9s 564ms/step - loss: 0.0129 - val_loss: 0.1625
# Epoch 142/200
# 16/16 [==============================] - 9s 567ms/step - loss: 0.0138 - val_loss: 0.1638
# Epoch 143/200
# 16/16 [==============================] - 9s 562ms/step - loss: 0.0142 - val_loss: 0.1651
# Epoch 144/200
# 16/16 [==============================] - 9s 563ms/step - loss: 0.0135 - val_loss: 0.1650
# Epoch 145/200
# 16/16 [==============================] - 9s 564ms/step - loss: 0.0127 - val_loss: 0.1650
# Epoch 146/200
# 16/16 [==============================] - 9s 564ms/step - loss: 0.0138 - val_loss: 0.1639
# Epoch 147/200
# 16/16 [==============================] - 9s 561ms/step - loss: 0.0141 - val_loss: 0.1638
# Epoch 148/200
# 16/16 [==============================] - 9s 564ms/step - loss: 0.0121 - val_loss: 0.1635
# Epoch 149/200
# 16/16 [==============================] - 9s 569ms/step - loss: 0.0115 - val_loss: 0.1621
# Epoch 150/200
# 16/16 [==============================] - 9s 564ms/step - loss: 0.0119 - val_loss: 0.1632
# Epoch 151/200
# 16/16 [==============================] - 9s 561ms/step - loss: 0.0119 - val_loss: 0.1648
# Epoch 152/200
# 16/16 [==============================] - 9s 569ms/step - loss: 0.0117 - val_loss: 0.1636
# Epoch 153/200
# 16/16 [==============================] - 9s 564ms/step - loss: 0.0137 - val_loss: 0.1639
# Epoch 154/200
# 16/16 [==============================] - 9s 565ms/step - loss: 0.0128 - val_loss: 0.1617
# Epoch 155/200
# 16/16 [==============================] - 9s 565ms/step - loss: 0.0123 - val_loss: 0.1627
# Epoch 156/200
# 16/16 [==============================] - 9s 566ms/step - loss: 0.0117 - val_loss: 0.1617
# Epoch 157/200
# 16/16 [==============================] - 9s 564ms/step - loss: 0.0098 - val_loss: 0.1605
# Epoch 158/200
# 16/16 [==============================] - 9s 565ms/step - loss: 0.0114 - val_loss: 0.1602
# Epoch 159/200
# 16/16 [==============================] - 9s 560ms/step - loss: 0.0104 - val_loss: 0.1604
# Epoch 160/200
# 16/16 [==============================] - 9s 568ms/step - loss: 0.0129 - val_loss: 0.1615
# Epoch 161/200
# 16/16 [==============================] - 9s 563ms/step - loss: 0.0106 - val_loss: 0.1604
# Epoch 162/200
# 16/16 [==============================] - 9s 561ms/step - loss: 0.0111 - val_loss: 0.1585
# Epoch 163/200
# 16/16 [==============================] - 9s 565ms/step - loss: 0.0093 - val_loss: 0.1595
# Epoch 164/200
# 16/16 [==============================] - 9s 560ms/step - loss: 0.0110 - val_loss: 0.1626
# Epoch 165/200
# 16/16 [==============================] - 9s 559ms/step - loss: 0.0110 - val_loss: 0.1620
# Epoch 166/200
# 16/16 [==============================] - 9s 566ms/step - loss: 0.0113 - val_loss: 0.1638
# Epoch 167/200
# 16/16 [==============================] - 9s 577ms/step - loss: 0.0106 - val_loss: 0.1602
# Epoch 168/200
# 16/16 [==============================] - 9s 561ms/step - loss: 0.0114 - val_loss: 0.1595
# Epoch 169/200
# 16/16 [==============================] - 9s 561ms/step - loss: 0.0112 - val_loss: 0.1583
# Epoch 170/200
# 16/16 [==============================] - 9s 562ms/step - loss: 0.0135 - val_loss: 0.1576
# Epoch 171/200
# 16/16 [==============================] - 9s 565ms/step - loss: 0.0112 - val_loss: 0.1590
# Epoch 172/200
# 16/16 [==============================] - 9s 561ms/step - loss: 0.0103 - val_loss: 0.1579
# Epoch 173/200
# 16/16 [==============================] - 9s 563ms/step - loss: 0.0102 - val_loss: 0.1584
# Epoch 174/200
# 16/16 [==============================] - 9s 568ms/step - loss: 0.0096 - val_loss: 0.1594
# Epoch 175/200
# 16/16 [==============================] - 9s 561ms/step - loss: 0.0118 - val_loss: 0.1587
# Epoch 176/200
# 16/16 [==============================] - 9s 564ms/step - loss: 0.0137 - val_loss: 0.1565
# Epoch 177/200
# 16/16 [==============================] - 9s 558ms/step - loss: 0.0150 - val_loss: 0.1564
# Epoch 178/200
# 16/16 [==============================] - 10s 624ms/step - loss: 0.0131 - val_loss: 0.1569
# Epoch 179/200
# 16/16 [==============================] - 10s 641ms/step - loss: 0.0105 - val_loss: 0.1570
# Epoch 180/200
# 16/16 [==============================] - 9s 565ms/step - loss: 0.0117 - val_loss: 0.1561
# Epoch 181/200
# 16/16 [==============================] - 9s 570ms/step - loss: 0.0101 - val_loss: 0.1583
# Epoch 182/200
# 16/16 [==============================] - 9s 563ms/step - loss: 0.0098 - val_loss: 0.1572
# Epoch 183/200
# 16/16 [==============================] - 9s 561ms/step - loss: 0.0083 - val_loss: 0.1555
# Epoch 184/200
# 16/16 [==============================] - 9s 560ms/step - loss: 0.0090 - val_loss: 0.1567
# Epoch 185/200
# 16/16 [==============================] - 9s 566ms/step - loss: 0.0107 - val_loss: 0.1559
# Epoch 186/200
# 16/16 [==============================] - 9s 568ms/step - loss: 0.0103 - val_loss: 0.1557
# Epoch 187/200
# 16/16 [==============================] - 9s 568ms/step - loss: 0.0094 - val_loss: 0.1556
# Epoch 188/200
# 16/16 [==============================] - 9s 566ms/step - loss: 0.0102 - val_loss: 0.1582
# Epoch 189/200
# 16/16 [==============================] - 9s 563ms/step - loss: 0.0099 - val_loss: 0.1559
# Epoch 190/200
# 16/16 [==============================] - 9s 559ms/step - loss: 0.0101 - val_loss: 0.1554
# Epoch 191/200
# 16/16 [==============================] - 9s 569ms/step - loss: 0.0103 - val_loss: 0.1562
# Epoch 192/200
# 16/16 [==============================] - 9s 577ms/step - loss: 0.0109 - val_loss: 0.1564
# Epoch 193/200
# 16/16 [==============================] - 9s 562ms/step - loss: 0.0101 - val_loss: 0.1573
# Epoch 194/200
# 16/16 [==============================] - 9s 564ms/step - loss: 0.0099 - val_loss: 0.1549
# Epoch 195/200
# 16/16 [==============================] - 9s 573ms/step - loss: 0.0094 - val_loss: 0.1555
# Epoch 196/200
# 16/16 [==============================] - 9s 576ms/step - loss: 0.0095 - val_loss: 0.1540
# Epoch 197/200
# 16/16 [==============================] - 9s 563ms/step - loss: 0.0082 - val_loss: 0.1549
# Epoch 198/200
# 16/16 [==============================] - 9s 566ms/step - loss: 0.0116 - val_loss: 0.1554
# Epoch 199/200
# 16/16 [==============================] - 9s 568ms/step - loss: 0.0102 - val_loss: 0.1538
# Epoch 200/200
# 16/16 [==============================] - 9s 566ms/step - loss: 0.0109 - val_loss: 0.1555

# %%
X_im_test.shape, X_im_train.shape
# Out:
# ((62, 240, 240, 3), (245, 240, 240, 3))

# %% [markdown]
# Now let's look at the training process history, we can see that both the loss metric and the root mean squared error are high at the beginning and decrease gradually through the epochs, we can notice how the validation metric is always higher than the metric obtained with the training data.

# %%
plt.figure(figsize=(16,6))
plt.plot(history.history["loss"], label = "Train Loss")
plt.plot(history.history["val_loss"], label = "Val Loss")
plt.xlabel("Epochs", fontsize = 14)
plt.ylabel("Loss", fontsize = 14)
plt.grid()
plt.legend(loc = "best")

# %% [markdown]
# ### 5.3 Model prediction
#
# In this case let's do some manipulations before to start with the predictions.

# %%
#Getting predictions on test data
predictions = model.predict([X_num_test_scaled,X_im_test]).flatten()

#transforming the data to the normal scale
max_price = max(Y_train)
predictions = predictions * max_price

# %%
plt.figure(figsize = (8,8))
plt.scatter(predictions, Y_test)
plt.title("Predictions vs Real", fontsize = 18)
plt.xlabel("Predictions", fontsize = 14)
plt.ylabel("Real", fontsize = 14)
plt.grid()

# %% [markdown]
# In the figure above we can see how the model predicts the majority of the values, however, there are some values which do not match with the prediction.
#
# ### 5.4 Model evaluation
#
# Let's use some commun metrics used to evaluate regression models, this will be:
#
# + Mean Absolute Error (MAE)
# + Root Mean Squared Error (RMSE)

# %%
#error
error = predictions-Y_test

#mean absolute error 
mae = np.round(np.mean(np.abs(error)),2)

#root mean squared error
rmse = np.round(np.sqrt(np.mean(np.square(error))),2)

# %%
#error plot
plt.figure(figsize = (16,6))
plt.scatter(range(len(Y_test)), error)
plt.ylabel("Error", fontsize = 14)
plt.xlabel("Index", fontsize = 14)
plt.title("Error plot")
plt.grid()

# %%
print(f"MAE: {mae} RMSE: {rmse}")
# Out:
# MAE: 108860.01 RMSE: 134681.45

# %% [markdown]
# The MAE is around $ 100 k this implies a poor performance, however if we do not take into account the big values the performance would be better, for example, let's use the median instead of the mean value to calculate a new metric.

# %%
mdae = np.round(np.median(np.abs(error)),2)

print(f"MDAE: {mdae}")
# Out:
# MDAE: 96141.48

# %% [markdown]
# Since the median is more robust against anomalous values we have a better metric value, however we need to improve this model.

# %% [markdown]
# <div class="alert alert-info" style="background-color:#006a79; color:white; padding:0px 10px; border-radius:5px;"><h2 style='margin:10px 5px'>6. Improve the model.</h2>
# </div>
#
# ### 6.1 Handle the outlier values
#
# Let's remove the outlier values to improve the model performance. Let's remove all the houses with price higher than $ 700 k

# %%
df2 = df[(df["price"]<= 700000) & (df["area"]<=8000) & (df["bedrooms"]<=7)]

df2.shape
# Out:
# (307, 14)

# %%
# Check the distribution of the area and price columns
df2[["area","price", "bedrooms","bathrooms"]].hist(figsize=(16,6),bins = 15)
plt.show()

# %%
# Check the distribution of each variable
fig,ax = plt.subplots(nrows = 1, ncols = 4, figsize=(16,6))
for i,label in enumerate(["area","price", "bedrooms","bathrooms"]):
    sn.boxplot(x = df2[label].values, orient = "v" ,ax = ax[i])
    ax[i].set_title(label)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 6.2 Scaling the data

# %%
processed_df2 = scaling_splitting_data(df2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-3837bc5b5b9c> in <module>
# ----> 1 processed_df2 = scaling_splitting_data(df2)
#
# NameError: name 'scaling_splitting_data' is not defined

# %% [markdown]
# ### 6.3 Building new model

# %%
model2 = create_model(processed_df2)

# %% [markdown]
# ### 6.4 Training the new model.

# %%
#use adam optimizer
optimizer = tf.keras.optimizers.Adam(lr=0.001)

#use mean absolute error as loss function
model2.compile(optimizer= optimizer, loss="mae")

#train the model
history_model2 = model2.fit(
    x = processed_df2["x_train_scaled"],
    y = processed_df2["y_train_scaled"],
    epochs = 200,
    validation_data = (processed_df2["x_test_scaled"], processed_df2["y_test_scaled"]),
    batch_size = 16,
    verbose = 0
)

# %%
plt.figure(figsize=(16,6))
plt.plot(history_model2.history["loss"], label = "Train Loss")
plt.plot(history_model2.history["val_loss"], label = "Val Loss")
plt.xlabel("Epochs", fontsize = 14)
plt.ylabel("Loss", fontsize = 14)
plt.grid()
plt.legend(loc = "best")

# %% [markdown]
# ### 6.5 Model prediction

# %%
#Getting predictions on test data
predictions2 = model2.predict(processed_df2["x_test_scaled"]).flatten()

#transforming the data to the normal scale
max_price2 = max(processed_df2["y_train"])
predictions2 = predictions2 * max_price2

# %%
plt.figure(figsize = (8,8))
plt.scatter(predictions2, processed_df2["y_test"])
plt.title("Predictions vs Real", fontsize = 18)
plt.xlabel("Predictions", fontsize = 14)
plt.ylabel("Real", fontsize = 14)
plt.grid()

# %% [markdown]
# ### 6.6 Model evaluation.

# %%
#error
error2 = predictions2-processed_df2["y_test"]

#mean absolute error 
mae2 = np.round(np.mean(np.abs(error2)),2)

#root mean squared error
rmse2 = np.round(np.sqrt(np.mean(np.square(error2))),2)

# %%
#error plot
plt.figure(figsize = (16,6))
plt.scatter(error2.index, error2.values)
plt.ylabel("Error", fontsize = 14)
plt.xlabel("Index", fontsize = 14)
plt.title("Error plot")
plt.grid()

# %%
print(f"MAE: {mae2} RMSE: {rmse2}")

# %%
mdae2 = np.round(np.median(np.abs(error2)),2)

print(f"MDAE: {mdae2}")

# %%
#Save the final data set used
df2.to_csv("output/final_house_price_prediction.csv", index = True)

# %% [markdown]
# ### 6.7 Saving the final model.

# %%
model2.save("output/house_price_regressor")

# %% [markdown]
# ### 7. Conclusions
#
# In this notebook we saw how to use the functional API of tensorflow to solve a regression problem. We also noticed how the presence of outliers affects the model performance. In the next part I am going to include the house image data to improve the house price prediction.
